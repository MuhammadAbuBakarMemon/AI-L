# %%
#The Environment 
# the external system with which the agent interacts, it provides the sensory inputs (percepts) and our agent responds to them 

class Environment:

    def __init__(self, initial_state):
        self.initial_state = initial_state          #initial state could be fixed or random 

    def get_percept(self):
        #initial condition of the environment that woould be perceived by the environmwnt 
        pass

# %%
#The Agent 
# the decision making entity that perceives it's environment and takes decisions to achieve a goal 

class SimpleReflexAgent:

    def __init__(self):
        pass

    def act(self, percept):
        
        #determine the action based on the initial percept 
        pass

# %%
#The Agent Program
# the internal mechanisim that determines the actions the agent takes based onn its percepts, the interactions allows for the agent to move within its environment 
# and effectively perform its functions 

def run_agent(agent, environment):

    #the agent recats to the initial stimulus/percept 

    percept = environment.get_percept()
    action = agent.act(percept)

    print(f'Percept: {percept}, Action: {action}')


#crating instances of the agent and the environment     
agent = SimpleReflexAgent()
# Start with any initial condition (high/low , 1/0, True/False , high/med/low etc based on scenario)
environment = Environment(initial_state = 0)

#runing the agent once 
run_agent(agent, environment)
# Out:
# Percept: None, Action: None
