# %%
'''
In Python attributes are variables that belong to a class, and are used to store data related to an object.

They are of 2 main types
1- Instance Attributes 
    Defined inside th __init__() constructor using self
    each object has its own copy of these attributes 
'''

class Student:
    school = 'Bahria College Karachi NORE-1'    #class attribute

s1 = Student()
s2 = Student()

print(s1.school)
print(s2.school)
# Out:
# Bahria College Karachi NORE-1
# Bahria College Karachi NORE-1

# %%
'''
2- Class Attributes 
    Defined directly inside the class outside any method 
    shared by all the instances of the class 

'''

class Student:

    def __init__(self, name, age):
        self.name = name    #instance attribute 
        self.age = age      #instance attribute 

s1 = Student('Muhammad Abu Bakar', 19)
s2 = Student('Muhammad Ali', 16)

print(s1.name, s1.age)
print(s2.name, s2.age)
# Out:
# Muhammad Abu Bakar 19
# Muhammad Ali 16

# %%
#PLEASE BE MINDFUL OF WHAT IS UPPERCASE AND WHAT IS LOWER CASE 
#IN PYTHON School != school 

#MODIFYING CLASS AND INSTANCE ATTRIBUTE 

class Student:

    School = 'NUCES' #class attribute shared by all

    def __init__(self, name, age):
        self.name = name    #instance attribute 
        self.age = age      #instance attribute 

    def display_info(self):
        print(f'Name: {self.name}')
        print(f"Age: {self.age}")
        print(f"School: {Student.School}")

# Creating student objects (instances)

Student1 = Student('Muhammad Abu Bakar', 20)
Student2 = Student('Muhammad Ali', 17)

# Displaying info
Student1.display_info()
print("\n------------\n")
Student2.display_info()

#modifying the instance attribute 
Student1.age = 16
print("\nAfter modifying the age of student 1:")
Student1.display_info()

#modifying the class attribute 
Student.School = 'Trinity College Dublin'
print("\nAfter updating the school name:")
Student1.display_info()
Student2.display_info()
# Out:
# Name: Muhammad Abu Bakar
# Age: 20
# School: NUCES
#
# ------------
#
# Name: Muhammad Ali
# Age: 17
# School: NUCES
#
# After modifying the age of student 1:
# Name: Muhammad Abu Bakar
# Age: 16
# School: NUCES
#
# After updating the school name:
# Name: Muhammad Abu Bakar
# Age: 16
# School: Trinity College Dublin
# Name: Muhammad Ali
# Age: 17
# School: Trinity College Dublin
